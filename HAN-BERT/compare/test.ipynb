# %% [markdown]
# # eRisk2017数据集

# %%
import os
with open ('/home/E22301339/scale_early_depress_detect-main/eRisk2017/test_golden_truth.txt','r+')as f:
   list_data=[]
   list_total=[]  # 存储positive抑郁的用户id
   for item in f.readlines():
      list_data.append(item.strip())
str=list_data[0][:-1].strip()
print(str)
print(list_data[0][len(list_data[0])-1])

for item in list_data:
   if(item[len(item)-1]=='1'):
      list_total.append(item[:-1].strip())
   else:
      break
print(len(list_total))

# %%
# 验证测试集中的文件帖子数是否和用户数量对得上，8200个文件，820个用户

import os
import shutil
from natsort import natsorted

path='/home/E22301339/scale_early_depress_detect-main/eRisk2017/eRisk2017_test'
filenames=natsorted(os.listdir(path))
set_data=set()
for item in filenames:
    index=item.find('_',5)
    set_data.add(item[:index])
    if item[:index] in list_total:
        shutil.move(path+'/'+item,'/home/E22301339/scale_early_depress_detect-main/eRisk2017/dataset/positive_examples_test/'+item)
    else:
        shutil.move(path+'/'+item,'/home/E22301339/scale_early_depress_detect-main/eRisk2017/dataset/negative_examples_test/'+item)
print(len(filenames))
print(len(set_data))

# %% [markdown]
# # eRisk2018数据集

# %%
import os
with open ('/home/E22301339/scale_early_depress_detect-main/eRisk2018/risk-golden-truth-test.txt','r+')as f:
   list_data=[]
   list_total=[]  # 存储positive抑郁的用户id
   for item in f.readlines():
      list_data.append(item.strip())
str=list_data[0][:-1].strip()
print(str)
print(list_data[0][len(list_data[0])-1])

for item in list_data:
   if(item[len(item)-1]=='1'):
      list_total.append(item[:-1].strip())
   else:
      break
print(len(list_total))

# %%
# 验证测试集中的文件帖子数是否和用户数量对得上，8200个文件，820个用户

import os
import shutil
from natsort import natsorted

path='/home/E22301339/scale_early_depress_detect-main/eRisk2018/eRisk2018_test'
filenames=natsorted(os.listdir(path))
set_data=set()
for item in filenames:
    index=item.find('_',5)
    set_data.add(item[:index])
    if item[:index] in list_total:
        shutil.move(path+'/'+item,'/home/E22301339/scale_early_depress_detect-main/eRisk2018/dataset/positive_examples_test/'+item)
    else:
        shutil.move(path+'/'+item,'/home/E22301339/scale_early_depress_detect-main/eRisk2018/dataset/negative_examples_test/'+item)
print(len(filenames))
print(len(set_data))

# %%
import os
import shutil

# 将eRisk2017的所有数据集复制到eRisk2018作为训练集
# files=["negative_examples_anonymous", "negative_examples_test", "positive_examples_anonymous", "positive_examples_test"]
# source_folder ='/home/E22301339/scale_early_depress_detect-main/eRisk2017/dataset'
# target_folder =
# Out:
# ==
